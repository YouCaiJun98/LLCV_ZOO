# %%
import glob
import random
from PIL import Image
import numpy as np
import torch
import torchvision
from torch.utils.data import Dataset

# randomly crop a patch from image
def crop_patch(im, pch_size):
  H = im.shape[0]
  W = im.shape[1]
  rnd_H = random.randint(0, H-pch_size)
  rnd_W = random.randint(0, W-pch_size)
  pch = im[rnd_H:rnd_H + pch_size, rnd_W:rnd_W + pch_size]
  return pch

# Needs TorchVision Implementation
def data_augmentation(image, mode):
    if mode == 0:
        # original
        out = image
    elif mode == 1:
        # flip up and down
        out = np.flipud(image)
    elif mode == 2:
        # rotate counterwise 90 degree
        out = np.rot90(image)
    elif mode == 3:
        # rotate 90 degree and flip up and down
        out = np.rot90(image)
        out = np.flipud(out)
    elif mode == 4:
        # rotate 180 degree
        out = np.rot90(image, k=2)
    elif mode == 5:
        # rotate 180 degree and flip
        out = np.rot90(image, k=2)
        out = np.flipud(out)
    elif mode == 6:
        # rotate 270 degree
        out = np.rot90(image, k=3)
    elif mode == 7:
        # rotate 270 degree and flip
        out = np.rot90(image, k=3)
        out = np.flipud(out)
    else:
        raise Exception('Invalid choice of image transformation')
    return out

def random_augmentation(*args):
    out = []
    flag_aug = random.randint(1,7)
    for data in args:
        out.append(data_augmentation(data, flag_aug).copy())
    return out

class BSD500_gray_Dataset(Dataset):
    def __init__(self, pth, length, patch_size, sigma):
        super(BSD500_gray_Dataset, self).__init__()
        self.len = length
        self.patch_size = patch_size
        self.sigma = sigma

        rgb2gray = torchvision.transforms.Grayscale(1)
        self.images = []
        self.num_images = 0
        for p in glob.glob(pth + '*.jpg'):
            img = Image.open(p)
            self.images.append(np.array(rgb2gray(img))[..., np.newaxis])
            self.num_images += 1

        self.transform = torchvision.transforms.ToTensor()

    def __getitem__(self, index):
        idx = random.randint(0, self.num_images - 1)
        img_patch =crop_patch(self.images[idx], self.patch_size)

        # generate gaussian noise N(0, sigma^2)
        noise = np.random.randn(*(img_patch.shape))
        noise_patch = np.clip(img_patch + noise * self.sigma, 0, 255).astype(np.uint8)
        
        aug_list = random_augmentation(img_patch, noise_patch)
        return self.transform(aug_list[1]), self.transform(aug_list[0])

    def __len__(self):
        return self.len

def image_show(x, title=None, cbar=False, figsize=None):
    import matplotlib.pyplot as plt
    plt.figure(figsize=figsize)
    plt.imshow(x, interpolation='nearest', cmap='gray')
    if title:
        plt.title(title)
    if cbar:
        plt.colorbar()
    plt.show()


if __name__ == '__main__':
    data_path = "BSD500/"
    batch_size = 1
    patch_size = 256
    train_samples = BSD500_gray_Dataset(data_path + 'train/', 100 * batch_size, patch_size, sigma=25)
    val_samples = BSD500_gray_Dataset(data_path + 'test/', 50 * batch_size, patch_size, sigma=25)
    train_loader = torch.utils.data.DataLoader(train_samples, batch_size=batch_size, shuffle=True, pin_memory=True)
    for step, (input, target) in enumerate(train_loader):
        input = input[0][0].numpy()
        target = target[0][0].numpy()
        image_show(input)
        image_show(target)
        import ipdb; ipdb.set_trace()
# Out:
# > <ipython-input-1-b6c367d5f67c>(107)<module>()
#     106     train_loader = torch.utils.data.DataLoader(train_samples, batch_size=batch_size, shuffle=True, pin_memory=True)
# --> 107     for step, (input, target) in enumerate(train_loader):
#     108         input = input[0][0].numpy()
#
# ipdb> c
# > <ipython-input-1-b6c367d5f67c>(107)<module>()
#     106     train_loader = torch.utils.data.DataLoader(train_samples, batch_size=batch_size, shuffle=True, pin_memory=True)
# --> 107     for step, (input, target) in enumerate(train_loader):
#     108         input = input[0][0].numpy()
#
# ipdb> c
# > <ipython-input-1-b6c367d5f67c>(107)<module>()
#     106     train_loader = torch.utils.data.DataLoader(train_samples, batch_size=batch_size, shuffle=True, pin_memory=True)
# --> 107     for step, (input, target) in enumerate(train_loader):
#     108         input = input[0][0].numpy()
#
# ipdb> input
# array([[0.        , 0.00784314, 0.        , ..., 0.4392157 , 0.42352942,
#         0.62352943],
#        [0.        , 0.16470589, 0.04705882, ..., 0.32156864, 0.07450981,
#         0.2784314 ],
#        [0.11764706, 0.        , 0.        , ..., 0.2784314 , 0.09411765,
#         0.08627451],
#        ...,
#        [0.        , 0.        , 0.11372549, ..., 0.8627451 , 0.69803923,
#         0.73333335],
#        [0.1882353 , 0.20784314, 0.14901961, ..., 0.7254902 , 0.7607843 ,
#         0.6117647 ],
#        [0.21176471, 0.02352941, 0.18039216, ..., 0.61960787, 0.7058824 ,
#         0.8901961 ]], dtype=float32)
# ipdb> n
# > <ipython-input-1-b6c367d5f67c>(108)<module>()
#     107     for step, (input, target) in enumerate(train_loader):
# --> 108         input = input[0][0].numpy()
#     109         target = target[0][0].numpy()
#
# ipdb> n
# > <ipython-input-1-b6c367d5f67c>(109)<module>()
#     108         input = input[0][0].numpy()
# --> 109         target = target[0][0].numpy()
#     110         image_show(input)
#
# ipdb> n
# > <ipython-input-1-b6c367d5f67c>(110)<module>()
#     109         target = target[0][0].numpy()
# --> 110         image_show(input)
#     111         image_show(target)
#
# ipdb> n
# > <ipython-input-1-b6c367d5f67c>(111)<module>()
#     110         image_show(input)
# --> 111         image_show(target)
#     112         import ipdb; ipdb.set_trace()
#
# ipdb> n
# > <ipython-input-1-b6c367d5f67c>(112)<module>()
#     110         image_show(input)
#     111         image_show(target)
# --> 112         import ipdb; ipdb.set_trace()
#
# ipdb> n
# > <ipython-input-1-b6c367d5f67c>(107)<module>()
#     106     train_loader = torch.utils.data.DataLoader(train_samples, batch_size=batch_size, shuffle=True, pin_memory=True)
# --> 107     for step, (input, target) in enumerate(train_loader):
#     108         input = input[0][0].numpy()
#
# ipdb> s
# --Call--
# > /home/shixiangsheng/miniconda3/envs/awnas/lib/python3.7/site-packages/torch/utils/data/dataloader.py(432)__next__()
#     431
# --> 432     def __next__(self) -> Any:
#     433         if self._sampler_iter is None:
#
# ipdb> n
# > /home/shixiangsheng/miniconda3/envs/awnas/lib/python3.7/site-packages/torch/utils/data/dataloader.py(433)__next__()
#     432     def __next__(self) -> Any:
# --> 433         if self._sampler_iter is None:
#     434             self._reset()
#
# ipdb> n
# > /home/shixiangsheng/miniconda3/envs/awnas/lib/python3.7/site-packages/torch/utils/data/dataloader.py(435)__next__()
#     434             self._reset()
# --> 435         data = self._next_data()
#     436         self._num_yielded += 1
#
# ipdb> n
# > /home/shixiangsheng/miniconda3/envs/awnas/lib/python3.7/site-packages/torch/utils/data/dataloader.py(436)__next__()
#     435         data = self._next_data()
# --> 436         self._num_yielded += 1
#     437         if self._dataset_kind == _DatasetKind.Iterable and \
#
# ipdb> n
# > /home/shixiangsheng/miniconda3/envs/awnas/lib/python3.7/site-packages/torch/utils/data/dataloader.py(437)__next__()
#     436         self._num_yielded += 1
# --> 437         if self._dataset_kind == _DatasetKind.Iterable and \
#     438                 self._IterableDataset_len_called is not None and \
#
# ipdb>
# > /home/shixiangsheng/miniconda3/envs/awnas/lib/python3.7/site-packages/torch/utils/data/dataloader.py(448)__next__()
#     447             warnings.warn(warn_msg)
# --> 448         return data
#     449
#
# ipdb> data
# [tensor([[[[0.0000, 0.1137, 0.2157,  ..., 0.2392, 0.3686, 0.3843],
#           [0.2627, 0.1255, 0.2157,  ..., 0.1608, 0.3373, 0.2039],
#           [0.3922, 0.2196, 0.1412,  ..., 0.3961, 0.3216, 0.2471],
#           ...,
#           [0.4235, 0.3765, 0.2980,  ..., 0.2118, 0.2039, 0.2784],
#           [0.2078, 0.1529, 0.2706,  ..., 0.1176, 0.2471, 0.2118],
#           [0.2706, 0.3137, 0.3098,  ..., 0.2824, 0.2157, 0.1725]]]]), tensor([[[[0.1490, 0.1608, 0.1725,  ..., 0.2549, 0.2549, 0.2549],
#           [0.1647, 0.1686, 0.1765,  ..., 0.2588, 0.2588, 0.2588],
#           [0.1725, 0.1765, 0.1882,  ..., 0.2627, 0.2627, 0.2627],
#           ...,
#           [0.3137, 0.3176, 0.3216,  ..., 0.2314, 0.2314, 0.2275],
#           [0.3059, 0.3098, 0.3137,  ..., 0.2275, 0.2275, 0.2275],
#           [0.2980, 0.3059, 0.3137,  ..., 0.2314, 0.2275, 0.2275]]]])]
# ipdb> n
# --Return--
# [tensor([[[[0....7, 0.1725]]]]), tensor([[[[0....5, 0.2275]]]])]
# > /home/shixiangsheng/miniconda3/envs/awnas/lib/python3.7/site-packages/torch/utils/data/dataloader.py(448)__next__()
#     447             warnings.warn(warn_msg)
# --> 448         return data
#     449
#
# ipdb> n
# > <ipython-input-1-b6c367d5f67c>(108)<module>()
#     107     for step, (input, target) in enumerate(train_loader):
# --> 108         input = input[0][0].numpy()
#     109         target = target[0][0].numpy()
#
# ipdb> n
# > <ipython-input-1-b6c367d5f67c>(109)<module>()
#     108         input = input[0][0].numpy()
# --> 109         target = target[0][0].numpy()
#     110         image_show(input)
#
# ipdb> n
# > <ipython-input-1-b6c367d5f67c>(110)<module>()
#     109         target = target[0][0].numpy()
# --> 110         image_show(input)
#     111         image_show(target)
# ipdb> n
# > <ipython-input-1-b6c367d5f67c>(111)<module>()
#     110         image_show(input)
# --> 111         image_show(target)
#     112         import ipdb; ipdb.set_trace()
#
# ipdb> n
# > <ipython-input-1-b6c367d5f67c>(112)<module>()
#     110         image_show(input)
#     111         image_show(target)
# --> 112         import ipdb; ipdb.set_trace()
#
# ipdb>
# > <ipython-input-1-b6c367d5f67c>(107)<module>()
#     106     train_loader = torch.utils.data.DataLoader(train_samples, batch_size=batch_size, shuffle=True, pin_memory=True)
# --> 107     for step, (input, target) in enumerate(train_loader):
#     108         input = input[0][0].numpy()
#
# ipdb> s
# --Call--
# > /home/shixiangsheng/miniconda3/envs/awnas/lib/python3.7/site-packages/torch/utils/data/dataloader.py(432)__next__()
#     431
# --> 432     def __next__(self) -> Any:
#     433         if self._sampler_iter is None:
#
# ipdb> n
# > /home/shixiangsheng/miniconda3/envs/awnas/lib/python3.7/site-packages/torch/utils/data/dataloader.py(433)__next__()
#     432     def __next__(self) -> Any:
# --> 433         if self._sampler_iter is None:
#     434             self._reset()
#
# ipdb> n
# > /home/shixiangsheng/miniconda3/envs/awnas/lib/python3.7/site-packages/torch/utils/data/dataloader.py(435)__next__()
#     434             self._reset()
# --> 435         data = self._next_data()
#     436         self._num_yielded += 1
#
# ipdb> s
# --Call--
# > /home/shixiangsheng/miniconda3/envs/awnas/lib/python3.7/site-packages/torch/utils/data/dataloader.py(473)_next_data()
#     472
# --> 473     def _next_data(self):
#     474         index = self._next_index()  # may raise StopIteration
#
# ipdb> n
# > /home/shixiangsheng/miniconda3/envs/awnas/lib/python3.7/site-packages/torch/utils/data/dataloader.py(474)_next_data()
#     473     def _next_data(self):
# --> 474         index = self._next_index()  # may raise StopIteration
#     475         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#
# ipdb> n
# > /home/shixiangsheng/miniconda3/envs/awnas/lib/python3.7/site-packages/torch/utils/data/dataloader.py(475)_next_data()
#     474         index = self._next_index()  # may raise StopIteration
# --> 475         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     476         if self._pin_memory:
#
# ipdb> s
# --Call--
# > /home/shixiangsheng/miniconda3/envs/awnas/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py(42)fetch()
#      41
# ---> 42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
#
# ipdb> n
# > /home/shixiangsheng/miniconda3/envs/awnas/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py(43)fetch()
#      42     def fetch(self, possibly_batched_index):
# ---> 43         if self.auto_collation:
#      44             data = [self.dataset[idx] for idx in possibly_batched_index]
#
# ipdb> n
# > /home/shixiangsheng/miniconda3/envs/awnas/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py(44)fetch()
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#
# ipdb> s
# --Call--
# > /home/shixiangsheng/miniconda3/envs/awnas/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py(44)<listcomp>()
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#
# ipdb> s
# > /home/shixiangsheng/miniconda3/envs/awnas/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py(44)<listcomp>()
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
# ipdb> s
# --Call--
# > <ipython-input-1-b6c367d5f67c>(75)__getitem__()
#      74
# ---> 75     def __getitem__(self, index):
#      76         idx = random.randint(0, self.num_images - 1)
#
# ipdb> n
# > <ipython-input-1-b6c367d5f67c>(76)__getitem__()
#      75     def __getitem__(self, index):
# ---> 76         idx = random.randint(0, self.num_images - 1)
#      77         img_patch =crop_patch(self.images[idx], self.patch_size)
#
# ipdb> n
# > <ipython-input-1-b6c367d5f67c>(77)__getitem__()
#      76         idx = random.randint(0, self.num_images - 1)
# ---> 77         img_patch =crop_patch(self.images[idx], self.patch_size)
#      78
#
# ipdb> self.images[idx]
# array([[[255],
#         [255],
#         [255],
#         ...,
#         [ 67],
#         [ 67],
#         [ 65]],
#
#        [[255],
#         [255],
#         [255],
#         ...,
#         [ 66],
#         [ 66],
#         [ 65]],
#
#        [[255],
#         [255],
#         [255],
#         ...,
#         [ 72],
#         [ 72],
#         [ 71]],
#
#        ...,
#
#        [[ 42],
#         [ 47],
#         [ 49],
#         ...,
#         [ 50],
#         [ 46],
#         [ 50]],
#
#        [[ 41],
#         [ 47],
#         [ 50],
#         ...,
#         [ 51],
#         [ 48],
#         [ 51]],
#
#        [[ 43],
#         [ 45],
#         [ 49],
#         ...,
#         [ 45],
#         [ 43],
#         [ 46]]], dtype=uint8)
# ipdb> n
# > <ipython-input-1-b6c367d5f67c>(80)__getitem__()
#      79         # generate gaussian noise N(0, sigma^2)
# ---> 80         noise = np.random.randn(*(img_patch.shape))
#      81         noise_patch = np.clip(img_patch + noise * self.sigma, 0, 255).astype(np.uint8)
#
# ipdb> img_patch
# array([[[185],
#         [162],
#         [ 59],
#         ...,
#         [ 71],
#         [107],
#         [211]],
#
#        [[250],
#         [233],
#         [140],
#         ...,
#         [ 73],
#         [ 84],
#         [195]],
#
#        [[251],
#         [212],
#         [172],
#         ...,
#         [ 80],
#         [ 74],
#         [106]],
#
#        ...,
#
#        [[130],
#         [166],
#         [221],
#         ...,
#         [ 42],
#         [ 42],
#         [ 43]],
#
#        [[125],
#         [181],
#         [212],
#         ...,
#         [ 42],
#         [ 42],
#         [ 43]],
#
#        [[145],
#         [221],
#         [195],
#         ...,
#         [ 42],
#         [ 43],
#         [ 43]]], dtype=uint8)
# ipdb> n
# > <ipython-input-1-b6c367d5f67c>(81)__getitem__()
#      80         noise = np.random.randn(*(img_patch.shape))
# ---> 81         noise_patch = np.clip(img_patch + noise * self.sigma, 0, 255).astype(np.uint8)
#      82
#
# ipdb> noise
# array([[[-2.55375366],
#         [-0.1737783 ],
#         [-0.76917487],
#         ...,
#         [-2.13917741],
#         [-1.12262144],
#         [-1.27465601]],
#
#        [[-0.57397252],
#         [-0.31609702],
#         [-0.46111598],
#         ...,
#         [ 0.73675898],
#         [-0.4169316 ],
#         [ 0.32420702]],
#
#        [[-0.56001538],
#         [ 0.26089776],
#         [ 0.8694604 ],
#         ...,
#         [ 2.14911662],
#         [ 0.34380383],
#         [ 1.09425171]],
#
#        ...,
#
#        [[-0.88442311],
#         [-0.28513518],
#         [-0.78477691],
#         ...,
#         [ 1.22592483],
#         [-0.32778747],
#         [-1.32474981]],
#
#        [[-0.31797343],
#         [ 0.59886818],
#         [-0.36257065],
#         ...,
#         [-0.02083177],
#         [-0.70629371],
#         [ 0.55913375]],
#
#        [[ 0.15829251],
#         [ 1.81888567],
#         [-1.33547271],
#         ...,
#         [ 0.60316173],
#         [-0.06765786],
#         [-0.04143503]]])
# ipdb> n
# > <ipython-input-1-b6c367d5f67c>(83)__getitem__()
#      82
# ---> 83         aug_list = random_augmentation(img_patch, noise_patch)
#      84         return self.transform(aug_list[1]), self.transform(aug_list[0])
#
# ipdb> img_patch
# array([[[185],
#         [162],
#         [ 59],
#         ...,
#         [ 71],
#         [107],
#         [211]],
#
#        [[250],
#         [233],
#         [140],
#         ...,
#         [ 73],
#         [ 84],
#         [195]],
#
#        [[251],
#         [212],
#         [172],
#         ...,
#         [ 80],
#         [ 74],
#         [106]],
#
#        ...,
#
#        [[130],
#         [166],
#         [221],
#         ...,
#         [ 42],
#         [ 42],
#         [ 43]],
#
#        [[125],
#         [181],
#         [212],
#         ...,
#         [ 42],
#         [ 42],
#         [ 43]],
#
#        [[145],
#         [221],
#         [195],
#         ...,
#         [ 42],
#         [ 43],
#         [ 43]]], dtype=uint8)
# ipdb> n
# > <ipython-input-1-b6c367d5f67c>(84)__getitem__()
#      83         aug_list = random_augmentation(img_patch, noise_patch)
# ---> 84         return self.transform(aug_list[1]), self.transform(aug_list[0])
#      85
#
# ipdb> aug_list[0]
# array([[[211],
#         [195],
#         [106],
#         ...,
#         [ 43],
#         [ 43],
#         [ 43]],
#
#        [[107],
#         [ 84],
#         [ 74],
#         ...,
#         [ 42],
#         [ 42],
#         [ 43]],
#
#        [[ 71],
#         [ 73],
#         [ 80],
#         ...,
#         [ 42],
#         [ 42],
#         [ 42]],
#
#        ...,
#
#        [[ 59],
#         [140],
#         [172],
#         ...,
#         [221],
#         [212],
#         [195]],
#
#        [[162],
#         [233],
#         [212],
#         ...,
#         [166],
#         [181],
#         [221]],
#
#        [[185],
#         [250],
#         [251],
#         ...,
#         [130],
#         [125],
#         [145]]], dtype=uint8)
# ipdb> n
# --Return--
# (tensor([[[0.7...88, 0.5804]]]), tensor([[[0.8...02, 0.5686]]]))
# > <ipython-input-1-b6c367d5f67c>(84)__getitem__()
#      83         aug_list = random_augmentation(img_patch, noise_patch)
# ---> 84         return self.transform(aug_list[1]), self.transform(aug_list[0])
#      85
#
# ipdb> img_patch
# array([[[185],
#         [162],
#         [ 59],
#         ...,
#         [ 71],
#         [107],
#         [211]],
#
#        [[250],
#         [233],
#         [140],
#         ...,
#         [ 73],
#         [ 84],
#         [195]],
#
#        [[251],
#         [212],
#         [172],
#         ...,
#         [ 80],
#         [ 74],
#         [106]],
#
#        ...,
#
#        [[130],
#         [166],
#         [221],
#         ...,
#         [ 42],
#         [ 42],
#         [ 43]],
#
#        [[125],
#         [181],
#         [212],
#         ...,
#         [ 42],
#         [ 42],
#         [ 43]],
#
#        [[145],
#         [221],
#         [195],
#         ...,
#         [ 42],
#         [ 43],
#         [ 43]]], dtype=uint8)
